# %% [markdown]
# # ***TEXT DETECTION (INTERNSHIP)***
#
# ---

# %% [markdown]
# **IMPORTING THE NECESSARY LIBRARIES**

# %%
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
import sys
import os
import csv
import pandas as pd
import cv2
import glob

# %% [markdown]
# **CREATING_DATASET**

# %%
file_list=glob.glob('/content/drive/MyDrive/dec_13_bookserb/*.*')
print(file_list)
# Out:
# ['/content/drive/MyDrive/dec_13_bookserb/image_2.jpg', '/content/drive/MyDrive/dec_13_bookserb/image_1.jpg', '/content/drive/MyDrive/dec_13_bookserb/image_3.jpg', '/content/drive/MyDrive/dec_13_bookserb/image_4.jpg', '/content/drive/MyDrive/dec_13_bookserb/image_5.jpg', '/content/drive/MyDrive/dec_13_bookserb/image_6.jpg', '/content/drive/MyDrive/dec_13_bookserb/image_8.jpg', '/content/drive/MyDrive/dec_13_bookserb/image_7.jpg', '/content/drive/MyDrive/dec_13_bookserb/image_10.jpg', '/content/drive/MyDrive/dec_13_bookserb/image_9.jpg', '/content/drive/MyDrive/dec_13_bookserb/image_11.jpg', '/content/drive/MyDrive/dec_13_bookserb/image_12.jpg', '/content/drive/MyDrive/dec_13_bookserb/image_13.jpg', '/content/drive/MyDrive/dec_13_bookserb/image_14.jpg', '/content/drive/MyDrive/dec_13_bookserb/image_16.jpg', '/content/drive/MyDrive/dec_13_bookserb/image_15.jpg']

# %% [markdown]
# file_list=glob.glob('/content/drive/MyDrive/dec_13_bookserb/*.*')
# print(file_list)

# %%
my_list=[]
path='/content/drive/MyDrive/dec_13_bookserb/*.*'
for file in glob.glob(path):
  print(file)
  a=cv2.imread(file)
  my_list.append(a)
# Out:
# /content/drive/MyDrive/dec_13_bookserb/image_2.jpg
# /content/drive/MyDrive/dec_13_bookserb/image_1.jpg
# /content/drive/MyDrive/dec_13_bookserb/image_3.jpg
# /content/drive/MyDrive/dec_13_bookserb/image_4.jpg
# /content/drive/MyDrive/dec_13_bookserb/image_5.jpg
# /content/drive/MyDrive/dec_13_bookserb/image_6.jpg
# /content/drive/MyDrive/dec_13_bookserb/image_8.jpg
# /content/drive/MyDrive/dec_13_bookserb/image_7.jpg
# /content/drive/MyDrive/dec_13_bookserb/image_10.jpg
# /content/drive/MyDrive/dec_13_bookserb/image_9.jpg
# /content/drive/MyDrive/dec_13_bookserb/image_11.jpg
# /content/drive/MyDrive/dec_13_bookserb/image_12.jpg
# /content/drive/MyDrive/dec_13_bookserb/image_13.jpg
# /content/drive/MyDrive/dec_13_bookserb/image_14.jpg
# /content/drive/MyDrive/dec_13_bookserb/image_16.jpg
# /content/drive/MyDrive/dec_13_bookserb/image_15.jpg

# %%
len(my_list)
# Out:
# 16

# %%
img=my_list[1]
plt.imshow(img)

# %%
path1=[]
Index=list(range(1,17))
for file in glob.glob(path):
  path1.append(file)

print(path1)
# Out:
# ['/content/drive/MyDrive/dec_13_bookserb/image_2.jpg', '/content/drive/MyDrive/dec_13_bookserb/image_1.jpg', '/content/drive/MyDrive/dec_13_bookserb/image_3.jpg', '/content/drive/MyDrive/dec_13_bookserb/image_4.jpg', '/content/drive/MyDrive/dec_13_bookserb/image_5.jpg', '/content/drive/MyDrive/dec_13_bookserb/image_6.jpg', '/content/drive/MyDrive/dec_13_bookserb/image_8.jpg', '/content/drive/MyDrive/dec_13_bookserb/image_7.jpg', '/content/drive/MyDrive/dec_13_bookserb/image_10.jpg', '/content/drive/MyDrive/dec_13_bookserb/image_9.jpg', '/content/drive/MyDrive/dec_13_bookserb/image_11.jpg', '/content/drive/MyDrive/dec_13_bookserb/image_12.jpg', '/content/drive/MyDrive/dec_13_bookserb/image_13.jpg', '/content/drive/MyDrive/dec_13_bookserb/image_14.jpg', '/content/drive/MyDrive/dec_13_bookserb/image_16.jpg', '/content/drive/MyDrive/dec_13_bookserb/image_15.jpg']

# %%
Dict_path={'index':Index ,'path': path1}

# %%
#CREATING DATAFRAME
data=pd.DataFrame(data=Dict_path)
data
# Out:
#     index                                               path
# 0       1  /content/drive/MyDrive/dec_13_bookserb/image_2...
# 1       2  /content/drive/MyDrive/dec_13_bookserb/image_1...
# 2       3  /content/drive/MyDrive/dec_13_bookserb/image_3...
# 3       4  /content/drive/MyDrive/dec_13_bookserb/image_4...
# 4       5  /content/drive/MyDrive/dec_13_bookserb/image_5...
# 5       6  /content/drive/MyDrive/dec_13_bookserb/image_6...
# 6       7  /content/drive/MyDrive/dec_13_bookserb/image_8...
# 7       8  /content/drive/MyDrive/dec_13_bookserb/image_7...
# 8       9  /content/drive/MyDrive/dec_13_bookserb/image_1...
# 9      10  /content/drive/MyDrive/dec_13_bookserb/image_9...
# 10     11  /content/drive/MyDrive/dec_13_bookserb/image_1...
# 11     12  /content/drive/MyDrive/dec_13_bookserb/image_1...
# 12     13  /content/drive/MyDrive/dec_13_bookserb/image_1...
# 13     14  /content/drive/MyDrive/dec_13_bookserb/image_1...
# ...

# %%
#CREATING CSV FILE
data.to_csv('internship_dataset.csv',index=False)

# %%
data=pd.read_csv(r'/content/internship_dataset.csv')
data
# Out:
#     index                                               path
# 0       1  /content/drive/MyDrive/dec_13_bookserb/image_2...
# 1       2  /content/drive/MyDrive/dec_13_bookserb/image_1...
# 2       3  /content/drive/MyDrive/dec_13_bookserb/image_3...
# 3       4  /content/drive/MyDrive/dec_13_bookserb/image_4...
# 4       5  /content/drive/MyDrive/dec_13_bookserb/image_5...
# 5       6  /content/drive/MyDrive/dec_13_bookserb/image_6...
# 6       7  /content/drive/MyDrive/dec_13_bookserb/image_8...
# 7       8  /content/drive/MyDrive/dec_13_bookserb/image_7...
# 8       9  /content/drive/MyDrive/dec_13_bookserb/image_1...
# 9      10  /content/drive/MyDrive/dec_13_bookserb/image_9...
# 10     11  /content/drive/MyDrive/dec_13_bookserb/image_1...
# 11     12  /content/drive/MyDrive/dec_13_bookserb/image_1...
# 12     13  /content/drive/MyDrive/dec_13_bookserb/image_1...
# 13     14  /content/drive/MyDrive/dec_13_bookserb/image_1...
# ...

# %%
data.describe()
# Out:
#            index
# count  16.000000
# mean    8.500000
# std     4.760952
# min     1.000000
# 25%     4.750000
# 50%     8.500000
# 75%    12.250000
# max    16.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   index   16 non-null     int64
#  1   path    16 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 384.0+ bytes

# %% [markdown]
# **IMAGE_PRE-PROCESSING**

# %%
#GRAYSCALE IMAGE
img_gray=cv2.cvtColor(img,cv2.COLOR_RGB2GRAY)
plt.imshow(img_gray,cmap='gray')

# %%
# Out:
# 255

# %%
#THRESHOLDING
rat,thresh=cv2.threshold(img_gray,200,255,cv2.THRESH_BINARY_INV,cv2.THRESH_OTSU)
plt.imshow(thresh,cmap='gray')

# %%
#GAUSSIAN BLUR
blur = cv2.GaussianBlur(thresh, (3,3), 0)
plt.imshow(blur,cmap='gray')
